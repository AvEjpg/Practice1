# %%
data1 = pd.read_excel('Material_type_import.xlsx')
data1.to_csv('Material_type_import.csv', sep=';', index=True)

# %%
data2 = pd.read_excel('Product_type_import.xlsx')
data2.to_csv('Product_type_import.csv', sep=';', index=True)

# %%
data3 = pd.read_excel('Product_workshops_import.xlsx')
data3.to_csv('Product_workshops_import.csv', sep=';', index=True)

# %%
data4 = pd.read_excel('Products_import.xlsx')
data4.to_csv('Products_import.csv', sep=';', index=True)

# %%
data5 = pd.read_excel('Workshops_import.xlsx')
data5.to_csv('Workshops_import.csv', sep=';', index=True)
